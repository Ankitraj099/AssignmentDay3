df.tail(5)
# Out:
#            0         1         2         3         4
# 35  0.158482  0.083459  0.970244  0.655072  0.837706
# 36  0.042164  0.246857  0.665914  0.967900  0.771261
# 37  0.416193  0.386487  0.109810  0.749150  0.631559
# 38  0.393727  0.808880  0.432461  0.046664  0.883824
# 39  0.680778  0.916064  0.817837  0.862875  0.694473

# %%
df.describe()
# Out:
#                0          1          2          3          4
# count  40.000000  40.000000  40.000000  40.000000  40.000000
# mean    0.539184   0.553581   0.468105   0.513423   0.547561
# std     0.323646   0.286629   0.269001   0.321685   0.263415
# min     0.006387   0.052909   0.047535   0.025529   0.047195
# 25%     0.290454   0.342953   0.284331   0.210878   0.386052
# 50%     0.473128   0.587851   0.411101   0.481848   0.581667
# 75%     0.845096   0.808091   0.629381   0.805280   0.729953
# max     0.972185   0.993126   0.970244   0.987437   0.970685

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       40 non-null     float64
#  1   1       40 non-null     float64
#  2   2       40 non-null     float64
#  3   3       40 non-null     float64
#  4   4       40 non-null     float64
# dtypes: float64(5)
# memory usage: 1.7 KB

# %% [markdown]
# **data selection

# %%
type(df["id"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 type(df["id"])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'id'

# %%
df.iloc[0]
# Out:
# 0    0.226416
# 1    0.407226
# 2    0.711010
# 3    0.956574
# 4    0.458486
# Name: 0, dtype: float64

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.dropna()
# Out:
#            0         1         2         3         4
# 0   0.226416  0.407226  0.711010  0.956574  0.458486
# 1   0.801928  0.893238  0.228686  0.804173  0.360654
# 2   0.385011  0.682505  0.336346  0.025529  0.435515
# 3   0.771576  0.547344  0.499090  0.753029  0.860993
# 4   0.311800  0.947751  0.390997  0.222175  0.047195
# 5   0.793170  0.604318  0.568441  0.980608  0.228129
# 6   0.890669  0.519398  0.072819  0.544515  0.590018
# 7   0.753737  0.727452  0.118360  0.028287  0.885134
# 8   0.064545  0.911368  0.328367  0.357828  0.275949
# 9   0.862354  0.418945  0.380652  0.808600  0.716183
# 10  0.419485  0.647974  0.286545  0.491550  0.670699
# 11  0.875484  0.878015  0.372406  0.814145  0.680218
# 12  0.006387  0.104695  0.527630  0.754343  0.910505
# 13  0.944397  0.268481  0.101828  0.411673  0.637899
# 14  0.022872  0.700721  0.914714  0.107228  0.573317
# 15  0.427542  0.614557  0.075360  0.465118  0.700397
# 16  0.823050  0.564705  0.289591  0.861623  0.773211
# ...

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# ** inplace changes into origibal data fraame , so it is not recommendable to use

# %% [markdown]
# **for chnaging coloumn name = df.rename(coloumns={"original name":"newname"},inplace=True)# inplace is used to do changes in origibal dta frame

# %%
df.describe()
# Out:
#                0          1          2          3          4
# count  40.000000  40.000000  40.000000  40.000000  40.000000
# mean    0.539184   0.553581   0.468105   0.513423   0.547561
# std     0.323646   0.286629   0.269001   0.321685   0.263415
# min     0.006387   0.052909   0.047535   0.025529   0.047195
# 25%     0.290454   0.342953   0.284331   0.210878   0.386052
# 50%     0.473128   0.587851   0.411101   0.481848   0.581667
# 75%     0.845096   0.808091   0.629381   0.805280   0.729953
# max     0.972185   0.993126   0.970244   0.987437   0.970685

# %%
df.info
# Out:
# <bound method DataFrame.info of            0         1         2         3         4
# 0   0.226416  0.407226  0.711010  0.956574  0.458486
# 1   0.801928  0.893238  0.228686  0.804173  0.360654
# 2   0.385011  0.682505  0.336346  0.025529  0.435515
# 3   0.771576  0.547344  0.499090  0.753029  0.860993
# 4   0.311800  0.947751  0.390997  0.222175  0.047195
# 5   0.793170  0.604318  0.568441  0.980608  0.228129
# 6   0.890669  0.519398  0.072819  0.544515  0.590018
# 7   0.753737  0.727452  0.118360  0.028287  0.885134
# 8   0.064545  0.911368  0.328367  0.357828  0.275949
# 9   0.862354  0.418945  0.380652  0.808600  0.716183
# 10  0.419485  0.647974  0.286545  0.491550  0.670699
# 11  0.875484  0.878015  0.372406  0.814145  0.680218
# 12  0.006387  0.104695  0.527630  0.754343  0.910505
# 13  0.944397  0.268481  0.101828  0.411673  0.637899
# 14  0.022872  0.700721  0.914714  0.107228  0.573317
# 15  0.427542  0.614557  0.075360  0.465118  0.700397
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       40 non-null     float64
#  1   1       40 non-null     float64
#  2   2       40 non-null     float64
#  3   3       40 non-null     float64
#  4   4       40 non-null     float64
# dtypes: float64(5)
# memory usage: 1.7 KB

# %% [markdown]
# ** for changing coloumn datatype df.['coloumnname']=df.['coloumnname'].astype(new datatype)

# %% [markdown]
# len(df)** gives rows

# %%
df["zeros"]= [0 for i in range(len(df))]

# %%
df
# Out:
#            0         1         2         3         4  zeros
# 0   0.226416  0.407226  0.711010  0.956574  0.458486      0
# 1   0.801928  0.893238  0.228686  0.804173  0.360654      0
# 2   0.385011  0.682505  0.336346  0.025529  0.435515      0
# 3   0.771576  0.547344  0.499090  0.753029  0.860993      0
# 4   0.311800  0.947751  0.390997  0.222175  0.047195      0
# 5   0.793170  0.604318  0.568441  0.980608  0.228129      0
# 6   0.890669  0.519398  0.072819  0.544515  0.590018      0
# 7   0.753737  0.727452  0.118360  0.028287  0.885134      0
# 8   0.064545  0.911368  0.328367  0.357828  0.275949      0
# 9   0.862354  0.418945  0.380652  0.808600  0.716183      0
# 10  0.419485  0.647974  0.286545  0.491550  0.670699      0
# 11  0.875484  0.878015  0.372406  0.814145  0.680218      0
# 12  0.006387  0.104695  0.527630  0.754343  0.910505      0
# 13  0.944397  0.268481  0.101828  0.411673  0.637899      0
# 14  0.022872  0.700721  0.914714  0.107228  0.573317      0
# ...

# %%
df.rename(columns={"zeros":"ones"},inplace=True)

# %%
df.head(5)
# Out:
#           0         1         2         3         4  ones
# 0  0.226416  0.407226  0.711010  0.956574  0.458486     0
# 1  0.801928  0.893238  0.228686  0.804173  0.360654     0
# 2  0.385011  0.682505  0.336346  0.025529  0.435515     0
# 3  0.771576  0.547344  0.499090  0.753029  0.860993     0
# 4  0.311800  0.947751  0.390997  0.222175  0.047195     0

# %%
def fx(a):
    return a**a
df["ones +1 "]=df["o"].apply(fx)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 3
#       1 def fx(a):
#       2     return a**a
# ...

# %%
df
# Out:
#            0         1         2         3         4  ones  ones +1
# 0   0.226416  0.407226  0.711010  0.956574  0.458486     0         1
# 1   0.801928  0.893238  0.228686  0.804173  0.360654     0         1
# 2   0.385011  0.682505  0.336346  0.025529  0.435515     0         1
# 3   0.771576  0.547344  0.499090  0.753029  0.860993     0         1
# 4   0.311800  0.947751  0.390997  0.222175  0.047195     0         1
# 5   0.793170  0.604318  0.568441  0.980608  0.228129     0         1
# 6   0.890669  0.519398  0.072819  0.544515  0.590018     0         1
# 7   0.753737  0.727452  0.118360  0.028287  0.885134     0         1
# 8   0.064545  0.911368  0.328367  0.357828  0.275949     0         1
# 9   0.862354  0.418945  0.380652  0.808600  0.716183     0         1
# 10  0.419485  0.647974  0.286545  0.491550  0.670699     0         1
# 11  0.875484  0.878015  0.372406  0.814145  0.680218     0         1
# 12  0.006387  0.104695  0.527630  0.754343  0.910505     0         1
# ...

# %%
df_students = pd.DataFrame({
    "student_id": [1, 2, 3, 4],
    "name": ["Ankit", "Riya", "Rahul", "Sneha"],
    "age": [21, 22, 20, 23]
})

# %%
df_marks = pd.DataFrame({
    "student_id": [1, 2, 4, 5],
    "math_marks": [85, 90, 88, 76]
})

# %%
df_students
# Out:
#    student_id   name  age
# 0           1  Ankit   21
# 1           2   Riya   22
# 2           3  Rahul   20
# 3           4  Sneha   23

# %%
df_marks
# Out:
#    student_id  math_marks
# 0           1          85
# 1           2          90
# 2           4          88
# 3           5          76

# %%
pd.concat([df_marks,df_students])
# Out:
#    student_id  math_marks   name   age
# 0           1        85.0    NaN   NaN
# 1           2        90.0    NaN   NaN
# 2           4        88.0    NaN   NaN
# 3           5        76.0    NaN   NaN
# 0           1         NaN  Ankit  21.0
# 1           2         NaN   Riya  22.0
# 2           3         NaN  Rahul  20.0
# 3           4         NaN  Sneha  23.0

# %%
pd.merge(df_students,df_marks, on="student_id")
# Out:
#    student_id   name  age  math_marks
# 0           1  Ankit   21          85
# 1           2   Riya   22          90
# 2           4  Sneha   23          88
